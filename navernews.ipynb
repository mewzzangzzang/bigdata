# %%
from konlpy.tag import *
kkma=Kkma()

# %%
from nltk import Text
import matplotlib.pylab as plt
from matplotlib import font_manager, rc
# 한글처리

# %%
fontname='c:/Windows/fonts/malgun.ttf'
# 한글폰트 
font_name=font_manager.FontProperties(fname=fontname).get_name()
rc('font',family=font_name)

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os 
import sys
import urllib.request
import json
client_id='9bLbOBlav89U3DdVt3iO'
client_secret='VGEXL3fXtT'
encText = urllib.parse.quote("가챠")
url = "https://openapi.naver.com/v1/search/news?query=" + encText + "&display=100"
# 100가지 추출
# url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
# 네이버에서는 헤더필요
response = urllib.request.urlopen(request)
# 요청이 정상적이라면 
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    res_body = json.loads(response_body.decode('utf-8')) # 한글 디코드 utf 필요함
    print(res_body['items'])
    str1=""
    
    # 특정 카테고리(title),(description) 추출
    for item in res_body['items']:
        str1+=item['title']+" "
        print(item['title'])
        print(item['description'])
else:
    print("Error Code:" + rescode)
# Out:
# [{'title': '[기자가 간다] 넷마블 ‘세븐나이츠 키우기’, 캐주얼 3박자로 빚은 방치형 게...', 'originallink': 'http://theviewers.co.kr/View.aspx?No=2935685', 'link': 'http://theviewers.co.kr/View.aspx?No=2935685', 'description': '주요 BM(비즈니스 모델)은 인 게임 광고 관련과 <b>가챠</b>인 소환, 그리고 코스튬 등이다. 별도의 패스권도 판매한다. 방치형 장르 게임은 기존 RPG 게임과 달리 게임 내 광고 매출 비중이 높다. 더 빠르게 강해지고 싶은... ', 'pubDate': 'Wed, 06 Sep 2023 17:30:00 +0900'}, {'title': "[한탕주의 사회, 쇼핑도 게임도 도박]③ '확률'에 몸살 앓던 게임업계, 결국 ...", 'originallink': 'https://www.ajunews.com/view/20230829144947949', 'link': 'https://www.ajunews.com/view/20230829144947949', 'description': "최종 아이템을 뽑기 위해 두 차례 이상 뽑기를 강제하는 '컴플리트 <b>가챠</b>(이중 뽑기)' 등으로 변형되기도... 당초 컴플리트 <b>가챠</b>를 원천 금지하는 법안도 함께 논의됐다가 게임업계 반대 등으로 인해 불발되면서 이러한... ", 'pubDate': 'Thu, 31 Aug 2023 04:32:00 +0900'}, {'title': '확률형 아이템 개정안 입법 예고 임박', 'originallink': 'http://www.tgdaily.co.kr/news/articleView.html?idxno=327318', 'link': 'http://www.tgdaily.co.kr/news/articleView.html?idxno=327318', 'description': '구체적인 시행령이 발표된 후 공개된 정보를 각 업체들이 대
# ...

# %%
news=kkma.nouns(str1)
news
# Out:
# ['기자',
#  '넷',
#  '넷마블',
#  '마블',
#  '나이',
#  '나이츠',
#  '츠',
#  '캐주얼',
#  '3',
#  '3박자',
#  '박자',
#  '빚',
#  '방치',
#  '방치형',
#  '형',
#  '게',
#  '한탕주의',
#  '사회',
#  '쇼핑',
#  '게임',
#  '도박',
#  '확률',
#  '몸살',
#  '게임업계',
#  '업계',
#  '결국',
#  '확률형',
#  '아이템',
#  '개정안',
#  '입법',
#  '예고',
#  '임박',
#  '직구',
#  '인기',
#  '웹툰',
#  '메',
#  '메이드',
#  '이드',
#  '개발',
#  '개발사가',
#  '사가',
#  '신작',
#  '신',
#  '탑',
#  '새',
#  '아이',
#  '레',
#  '레이브',
#  '이브',
#  '2023',
#  '트렌드',
#  '트렌드페어',
#  '페어',
#  '참가',
#  '외부',
#  '9',
#  '9월',
#  '월',
#  '세븐나이츠',
#  '체면',
#  '살리나',
#  '고',
#  '고난이도',
#  '난이도',
#  '액션',
#  '모바일',
#  '킹',
#  '킹덤',
#  '덤',
#  '왕가',
#  '피',
#  '체험',
#  '체험기',
#  '기',
#  '바람',
#  '나라',
#  '1',
#  '1만',
#  '만',
#  '일',
#  '시공',
#  '폭풍',
#  '속',
#  '개발실',
#  '실',
#  '파',
#  '파세대',
#  '세대',
#  '공략',
#  '콘텐츠',
#  '부족',
#  '숙제',
#  '한국',
#  '한국패션산업협회',
#  '패션',
#  '산업',
#  '협회',
#  '1층',
#  '층',
#  '홀',
#  '개최',
#  '8',
#  '23',
#  '25',
#  '23일',
#  '동',
#  '동영상',
#  '영상',
#  '미',
# ...

# %%
# 차트화를 위한 텍스트
news_tx=Text(news)
# 빈도수 구해서 워드 클라우드
often=news_tx.vocab()

# %%
# test 출력
from wordcloud import WordCloud
font_path='c:/Windows/fonts/malgun.ttf'
wc=WordCloud(width=10000,height=800, background_color='white',random_state=0,
             font_path=font_path)
plt.imshow(wc.generate_from_frequencies(often))
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud
from PIL import Image
# 이미지 객체사용
import numpy as np
import matplotlib.pyplot as plt
font_path='c:/Windows/fonts/malgun.ttf'
im=Image.open('images/c.jpg')
mask_arr=np.array(im)
mask_arr

wc=WordCloud(width=1000, height=1000, background_color='white',font_path=font_path,
             mask=mask_arr,random_state=0)
plt.imshow(wc.generate_from_frequencies(often))
plt.axis("off")
plt.show()
