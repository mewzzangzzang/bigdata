# %%
# pip install konlpy
# 아나콘다 프롬프터에서 설치하기
# JAVA_HOME 변수설정 
# path에 JAVA_HOME 두가지설정
# %JAVA_HOME%\bin
# %JAVA_HOME%\bin\server

from konlpy.tag import * 
hannanum=Hannanum()
kkma=Kkma()
komoran=Komoran()
okt=Okt()

# %%
from konlpy.corpus import kolaw
# 대한민국 헌법 말뭉치가져오기
kolaw.fileids()
# 필드설정
# Out:
# ['constitution.txt']

# %%
from konlpy.corpus import kobill
kobill.fileids()
# 국회법안 말뭉치
# Out:
# ['1809890.txt',
#  '1809891.txt',
#  '1809892.txt',
#  '1809893.txt',
#  '1809894.txt',
#  '1809895.txt',
#  '1809896.txt',
#  '1809897.txt',
#  '1809898.txt',
#  '1809899.txt']

# %%
c=kolaw.open('constitution.txt').read()
print(c[:50])
# 말뭉치 파일을 열어서 읽어오기
k=kobill.open("1809890.txt").read()
# 말뭉치 파일을 열어서읽어오기
print(k[:100])
# Out:
# 대한민국헌법
#
# 유구한 역사와 전통에 빛나는 우리 대한국민은 3·1운동으로 건립된 대한민국임
# 지방공무원법 일부개정법률안
#
# (정의화의원 대표발의 )
#
#  의 안
#  번 호
#
# 9890
#
# 발의연월일 : 2010.  11.  12.
#
# 발  의  자 : 정의화․이명수․김을동
#
# 이

# %% [markdown]
# # 형태소 분석기 공통적 기능
#  - nouns : 명사 추출
#  - mprphs : 형태소 추출
#  - pos : 형태소 추출과 품사태깅
#  결과 다름(원하는 방식의 추출모듈사용) 주의

# %%
c=kolaw.open('constitution.txt').read()
print(c[:50])
# Out:
# 대한민국헌법
#
# 유구한 역사와 전통에 빛나는 우리 대한국민은 3·1운동으로 건립된 대한민국임

# %%
print(c[:50])
# 명사만 추출하기
hannanum.nouns(c[:50])
# 단순 공백으로 구분해서 추출
# Out:
# 대한민국헌법
#
# 유구한 역사와 전통에 빛나는 우리 대한국민은 3·1운동으로 건립된 대한민국임
# ['대한민국헌법', '유구', '역사', '전통', '빛', '우리', '대한국민', '3·1운동', '건립', '대한민국임']

# %%
kkma.nouns(c[:50])
# 합성어 구분, 합해서 추출 한국의 언어방식에 부착적 (언어학적임)
# Out:
# ['대한',
#  '대한민국',
#  '대한민국헌법',
#  '민국',
#  '헌법',
#  '유구',
#  '역사',
#  '전통',
#  '우리',
#  '국민',
#  '3',
#  '1',
#  '1운동',
#  '운동',
#  '건립',
#  '대한민국임',
#  '임']

# %%
okt.nouns(c[:50])
# 줄임말도 하나의 명사로 구분, 아마도 명사적 형용사도 명사로 혼용하여 추출
# Out:
# ['대한민국', '헌법', '유구', '역사', '전통', '우리', '국민', '운동', '건립', '대한민국', '임']

# %%
komoran.nouns(c[:50])
# 합성어는 감가후 추출
# Out:
# ['대한민국', '헌법', '역사', '전통', '국민', '운동', '건립', '대한민국', '임']

# %% [markdown]
# 형태소 태깅방법 다름 주의!

# %%
s1='빅데이터 수업은 재미있지만 어려워요ㅜㅜ'
# okt.nouns(s1)
hannanum.pos(s1) 
# 원형에서 변형도 구분문자로 사용해서 구분(재미있-지-말(-ㄴ))
# okt.pos(s1)
# Out:
# [('빅데이터', 'N'),
#  ('수업', 'N'),
#  ('은', 'J'),
#  ('재미있', 'P'),
#  ('지', 'E'),
#  ('말', 'P'),
#  ('ㄴ', 'E'),
#  ('어려워요ㅜㅜ', 'N')]

# %%
hannanum.morphs(c[:50])
hannanum.pos(c[:50])
# Out:
# [('대한민국헌법', 'N'),
#  ('유구', 'N'),
#  ('하', 'X'),
#  ('ㄴ', 'E'),
#  ('역사', 'N'),
#  ('와', 'J'),
#  ('전통', 'N'),
#  ('에', 'J'),
#  ('빛', 'N'),
#  ('나는', 'J'),
#  ('우리', 'N'),
#  ('대한국민', 'N'),
#  ('은', 'J'),
#  ('3·1운동', 'N'),
#  ('으로', 'J'),
#  ('건립', 'N'),
#  ('되', 'X'),
#  ('ㄴ', 'E'),
#  ('대한민국임', 'N')]

# %%
kkma.morphs(c[:50])
kkma.pos(c[:50])
# Out:
# [('대한민국', 'NNG'),
#  ('헌법', 'NNG'),
#  ('유구', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('역사', 'NNG'),
#  ('와', 'JC'),
#  ('전통', 'NNG'),
#  ('에', 'JKM'),
#  ('빛나', 'VV'),
#  ('는', 'ETD'),
#  ('우리', 'NNM'),
#  ('대하', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('국민', 'NNG'),
#  ('은', 'JX'),
#  ('3', 'NR'),
#  ('·', 'SP'),
#  ('1', 'NR'),
#  ('운동', 'NNG'),
#  ('으로', 'JKM'),
#  ('건립', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('대한민국', 'NNG'),
#  ('임', 'NNG')]

# %%
komoran.morphs(c[:50])
komoran.pos(c[:50])
# Out:
# [('대한민국', 'NNP'),
#  ('헌법', 'NNP'),
#  ('유구', 'XR'),
#  ('하', 'XSA'),
#  ('ㄴ', 'ETM'),
#  ('역사', 'NNG'),
#  ('와', 'JC'),
#  ('전통', 'NNG'),
#  ('에', 'JKB'),
#  ('빛나', 'VV'),
#  ('는', 'ETM'),
#  ('우리', 'NP'),
#  ('대하', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('국민', 'NNP'),
#  ('은', 'JX'),
#  ('3', 'SN'),
#  ('·', 'SP'),
#  ('1', 'SN'),
#  ('운동', 'NNP'),
#  ('으로', 'JKB'),
#  ('건립', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('대한민국', 'NNP'),
#  ('임', 'NNP')]

# %%
okt.pos(c[:50])
# 영문으로 품사등등 구분해줌 가독성높음
# Out:
# [('대한민국', 'Noun'),
#  ('헌법', 'Noun'),
#  ('\n\n', 'Foreign'),
#  ('유구', 'Noun'),
#  ('한', 'Josa'),
#  ('역사', 'Noun'),
#  ('와', 'Josa'),
#  ('전통', 'Noun'),
#  ('에', 'Josa'),
#  ('빛나는', 'Verb'),
#  ('우리', 'Noun'),
#  ('대', 'Modifier'),
#  ('한', 'Modifier'),
#  ('국민', 'Noun'),
#  ('은', 'Josa'),
#  ('3', 'Number'),
#  ('·', 'Punctuation'),
#  ('1', 'Number'),
#  ('운동', 'Noun'),
#  ('으로', 'Josa'),
#  ('건립', 'Noun'),
#  ('된', 'Verb'),
#  ('대한민국', 'Noun'),
#  ('임', 'Noun')]

# %% [markdown]
# 태깅 태그셋 확인하기

# %%
kkma.tagset
# Out:
# {'EC': '연결 어미',
#  'ECD': '의존적 연결 어미',
#  'ECE': '대등 연결 어미',
#  'ECS': '보조적 연결 어미',
#  'EF': '종결 어미',
#  'EFA': '청유형 종결 어미',
#  'EFI': '감탄형 종결 어미',
#  'EFN': '평서형 종결 어미',
#  'EFO': '명령형 종결 어미',
#  'EFQ': '의문형 종결 어미',
#  'EFR': '존칭형 종결 어미',
#  'EP': '선어말 어미',
#  'EPH': '존칭 선어말 어미',
#  'EPP': '공손 선어말 어미',
#  'EPT': '시제 선어말 어미',
#  'ET': '전성 어미',
#  'ETD': '관형형 전성 어미',
#  'ETN': '명사형 전성 어미',
#  'IC': '감탄사',
#  'JC': '접속 조사',
#  'JK': '조사',
#  'JKC': '보격 조사',
#  'JKG': '관형격 조사',
#  'JKI': '호격 조사',
#  'JKM': '부사격 조사',
#  'JKO': '목적격 조사',
#  'JKQ': '인용격 조사',
#  'JKS': '주격 조사',
#  'JX': '보조사',
#  'MA': '부사',
#  'MAC': '접속 부사',
#  'MAG': '일반 부사',
#  'MD': '관형사',
#  'MDN': '수 관형사',
#  'MDT': '일반 관형사',
#  'NN': '명사',
#  'NNB': '일반 의존 명사',
#  'NNG': '보통명사',
#  'NNM': '단위 의존 명사',
#  'NNP': '고유명사',
#  'NP': '대명사',
#  'NR': '수사',
#  'OH': '한자',
#  'OL': '외국어',
#  'ON': '숫자',
#  'SE': '줄임표',
#  'SF': '마침표, 물음표, 느낌표',
#  'SO': '붙임표(물결,숨김,빠짐)',
#  'SP': '쉼표,가운뎃점,콜론,빗금',
#  'SS': '따옴표,괄호표,줄표',
# ...

# %%
from nltk import Text
import matplotlib.pylab as plt
from matplotlib import font_manager, rc
# 한글처리

# %%
fontname='c:/Windows/fonts/malgun.ttf'
# 한글폰트 
font_name=font_manager.FontProperties(fname=fontname).get_name()
rc('font',family=font_name)

# %%
okt.nouns(c)
# 명사추출하고, 텍스트에 넣어서 차팅
# Out:
# ['대한민국',
#  '헌법',
#  '유구',
#  '역사',
#  '전통',
#  '우리',
#  '국민',
#  '운동',
#  '건립',
#  '대한민국',
#  '임시정부',
#  '법',
#  '통과',
#  '불의',
#  '항거',
#  '민주',
#  '이념',
#  '계승',
#  '조국',
#  '민주',
#  '개혁',
#  '평화',
#  '통일',
#  '사명',
#  '입',
#  '각하',
#  '정의',
#  '인도',
#  '동포',
#  '애',
#  '로써',
#  '민족',
#  '단결',
#  '공고',
#  '모든',
#  '사회',
#  '폐습',
#  '불의',
#  '타파',
#  '자율',
#  '조화',
#  '바탕',
#  '자유민주',
#  '질서',
#  '더욱',
#  '정치',
#  '경제',
#  '사회',
#  '문화',
#  '모든',
#  '영역',
#  '각인',
#  '기회',
#  '능력',
#  '최고',
#  '도로',
#  '발휘',
#  '자유',
#  '권리',
#  '책임',
#  '의무',
#  '완수',
#  '안',
#  '국민',
#  '생활',
#  '향상',
#  '기하',
#  '밖',
#  '항구',
#  '세계',
#  '평화',
#  '인류',
#  '공영',
#  '이바지',
#  '함',
#  '우리',
#  '우리',
#  '자손',
#  '안전',
#  '자유',
#  '행복',
#  '확보',
#  '것',
#  '다짐',
#  '제정',
#  '차',
#  '개정',
#  '헌법',
#  '이제',
#  '국회',
#  '의결',
#  '국민투표',
#  '개정',
#  '제',
#  '장',
#  '강',
#  '제',
#  '대한민국',
#  '민주공화국',
#  '대한민국',
#  '주권',
#  '국민',
#  '모든',
#  '권력',
#  '국민',
#  '제',
#  '대한민국',
#  '국민',
#  '요건',
#  '법률',
# ...

# %%
kolaw_tx=Text(okt.nouns(c))
# okt형식으로 추출한 명사들을 text객체에 담아서
kolaw_tx.plot(30)
# 명사중 빈도수가 높은 30가지를 내림차순으로 차트화
plt.show()

# %%
# 빈도수 구하기
kv=kolaw_tx.vocab()
kv
# FreqDist
# Out:
# FreqDist({'제': 175, '법률': 127, '정': 89, '수': 88, '대통령': 83, '국가': 73, '국회': 68, '국민': 61, '관': 58, '때': 55, ...})

# %%
# 글자 수가 2자 이상인 것만 선택하기
kv2=dict()

# for tag,count in kv.items():
#   print(t)
# k와v

# 2글자 이상 추출
for tag,count in kv.items():
  if len(tag)>1:
    kv2[tag]=count
kv2
# Out:
# {'대한민국': 11,
#  '헌법': 53,
#  '유구': 1,
#  '역사': 1,
#  '전통': 1,
#  '우리': 3,
#  '국민': 61,
#  '운동': 2,
#  '건립': 1,
#  '임시정부': 1,
#  '통과': 1,
#  '불의': 2,
#  '항거': 1,
#  '민주': 6,
#  '이념': 1,
#  '계승': 2,
#  '조국': 3,
#  '개혁': 1,
#  '평화': 6,
#  '통일': 6,
#  '사명': 2,
#  '각하': 1,
#  '정의': 1,
#  '인도': 1,
#  '동포': 1,
#  '로써': 5,
#  '민족': 3,
#  '단결': 1,
#  '공고': 3,
#  '모든': 37,
#  '사회': 8,
#  '폐습': 1,
#  '타파': 1,
#  '자율': 2,
#  '조화': 2,
#  '바탕': 1,
#  '자유민주': 2,
#  '질서': 8,
#  '더욱': 1,
#  '정치': 9,
#  '경제': 18,
#  '문화': 4,
#  '영역': 4,
#  '각인': 1,
#  '기회': 3,
#  '능력': 3,
#  '최고': 2,
#  '도로': 1,
#  '발휘': 1,
#  '자유': 20,
#  '권리': 21,
#  '책임': 5,
#  '의무': 18,
#  '완수': 1,
#  '생활': 8,
#  '향상': 5,
#  '기하': 1,
#  '항구': 1,
#  '세계': 1,
#  '인류': 1,
#  '공영': 1,
#  '이바지': 1,
#  '자손': 1,
#  '안전': 1,
#  '행복': 2,
#  '확보': 1,
#  '다짐': 1,
#  '제정': 8,
#  '개정': 6,
#  '이제': 1,
#  '국회': 68,
#  '의결': 17,
#  '국민투표': 7,
#  '민주공화국': 1,
#  '주권': 2,
#  '권력': 1,
#  '요건': 1,
#  '법률': 127,
#  '국가': 73,
#  '재외국민': 1,
#  '보호': 14,
# ...

# %% [markdown]
# fontname='c:/Windows/fonts/malgun.ttf'
# font_name=font_manager.FontProperties(fname=fontname).get_name()
# rc('font',family=font_name)

# %%
from wordcloud import WordCloud
font_path='c:/Windows/fonts/malgun.ttf'
wc=WordCloud(width=10000,height=800, background_color='white',random_state=0,
             font_path=font_path)
plt.imshow(wc.generate_from_frequencies(kv))
plt.axis('off')
plt.savefig("data/wc_ko.png")
plt.show()

# %%
from collections import Counter
# 리스트안에 (문자열 내부에 카운팅)
s2="aaaabbbbbbbbxc"

sarr=list(s2)
print(sarr)

# 문자열을 리스트화
c1= Counter(sarr)
print(c1)
# 리스트안에 카운팅확인 파이썬 기본 라이브러리 내장
# Out:
# ['a', 'a', 'a', 'a', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'x', 'c']
# Counter({'b': 8, 'a': 4, 'x': 1, 'c': 1})

# %% [markdown]
# # 대한민국 법안 추출하고 , 카운팅하기

# %%
nouns1=okt.nouns(c)
counter1=Counter(nouns1)
print(counter1)
counter2=counter1.most_common(10)
print(counter2)

counter3=dict()
for tag,count in counter1.items():
  if (len(tag)>1) and (count>1): #글자수 2자이상, 빈도수 2 이상만 추출
    counter3[tag]=count
counter3
# Out:
# Counter({'제': 175, '법률': 127, '정': 89, '수': 88, '대통령': 83, '국가': 73, '국회': 68, '국민': 61, '관': 58, '때': 55, '헌법': 53, '그': 47, '이': 38, '모든': 37, '바': 37, '위': 36, '기타': 26, '및': 25, '사항': 23, '권리': 21, '안': 21, '의원': 21, '자유': 20, '정부': 20, '선거': 20, '임명': 20, '직무': 19, '국무총리': 19, '경제': 18, '의무': 18, '조직': 18, '국회의원': 18, '임기': 18, '의결': 17, '공무원': 17, '경우': 17, '이상': 17, '국무위원': 17, '대법원': 17, '범위': 16, '장': 15, '법관': 15, '보호': 14, '정책': 14, '정당': 14, '헌법재판소': 14, '재적': 14, '회의': 14, '항의': 14, '관리': 14, '노력': 13, '보장': 13, '거나': 13, '요구': 13, '법원': 12, '집회': 12, '과반수': 12, '출석': 12, '찬성': 12, '대한민국': 11, '조약': 11, '다만': 11, '재판': 11, '인': 11, '동의': 11, '탄핵': 11, '권한': 11, '안전보장': 10, '공포': 10, '대한': 10, '심판': 10, '시행': 10, '재판관': 10, '위원': 10, '정치': 9, '효력': 9, '대하': 9, '체포': 9, '절차': 9, '형사': 9, '근로': 9, '처분': 9, '위원회': 9, '행정각부': 9, '명령': 9, '사회': 8, '질서': 8, '생활': 8, '제정': 8, '인정': 8, '구속': 8, '구성': 8, '확정': 8, '상의': 8, '제출': 8, '항': 8, '국정': 8, '자문': 8, '사무': 8, '것': 7, '국민투표':
# ...

# %%
# 워드클라우드 생성
wc1=WordCloud(width=800,height=600, background_color='white', font_path=font_path,random_state=0)

plt.imshow(wc1.generate_from_frequencies(counter3))
plt.axis('off')
plt.show()

# %%
# 개인 네이버 뉴스 텍스트파일
data=open('data/data.txt').read()
data
# Out:
# '코로나19 이후 ‘마스크 없는’ 첫 추석 연휴가 최소 6일에서 최장 12일까지 이어지면서 김해국제공항 국내외 항공편과 부산 해운대 특급호텔이 크게 들썩인다. 5일 국무회의에서 추석 연휴와 개천절 사이에 낀 다음 달 2일을 임시공휴일로 의결하면서 이런 분위기는 더 확산할 것으로 보인다.\n\n\n부산 김해국제공항 국제선 청사가 항공편 탑승 수속을 밟는 여행객들로 북적이고 있다. 국제신문DB\n5일 국제신문 취재를 종합하면 추석 연휴 김해국제공항 국내외 항공편 예약률이 가파르게 오르고 있다. 이 기간 에어부산 국제선 항공편 예약률은 이미 90%를 넘어섰다. 일본 오사카·후쿠오카, 베트남 나트랑 노선 순으로 인기가 높다. 에어부산 국내선 항공편 예약률 역시 80%대에 달한다. 다음 달 3일(개천절) 부산으로 돌아오는 에어부산 국내선 항공편은 이미 만석이다.\n\n제주항공도 일본 노선에서 높은 예약률을 기록 중이다. 오사카가 90% 초반대, 도쿄·후쿠오카는 80% 중반대 예약이 이뤄졌다. 제주항공과 대한항공의 대만 등 동남아 국가 노선도 자리가 다 찼다. 연휴가 길어 상대적으로 거리가 먼 동남아·대양주 노선에도 여행객이 몰린 것으로 분석된다. 다음 달 2일이 임시공휴일로 지정돼 개인 휴가를 쓰면 추석 연휴 시작인 오는 28일부터 한글날인 다음 달 9일까지 최장 12일을 쉴 수 있다.\n\n해운대와 기장 해변을 따라 늘어선 지역 특급호텔 예약률도 80~90%대를 나타내고 있다. 해운대 A호텔은 오는 28~29일 예약률이 벌써 90%를 넘었다. B호텔은 오는 28일부터 다음 달 9일까지 평균 예약률이 80%를 넘길 것으로 예상된다. 지난해 추석 연휴 B호텔 평균 예약률은 70%대였다. C, D호텔도 추석 연휴 예약률이 80% 중반대를 기록하고 있다. 추석 연휴에다 다음 달 4일 개막하는 부산국제영화제 효과가 더해졌다. C호텔 관계자는 “다음 달 2일을 임시공휴일로 지정하는 방안이 논의된 이후 예약이 급증했다”고 말했다.\n\n직장인 3명 중 2명은 추석 연휴 여행에
# ...

# %%
# 명사추출
# okt 사용
okt.nouns(data)
# Out:
# ['코로나',
#  '이후',
#  '마스크',
#  '첫',
#  '추석',
#  '연휴',
#  '최소',
#  '최',
#  '김해',
#  '국제공항',
#  '국내외',
#  '항공',
#  '편',
#  '부산',
#  '해운대',
#  '특급',
#  '호텔',
#  '크게',
#  '국무회의',
#  '추석',
#  '연휴',
#  '개천절',
#  '사이',
#  '다음',
#  '달',
#  '임시',
#  '공휴일',
#  '의결',
#  '분위기',
#  '더',
#  '확산',
#  '것',
#  '부산',
#  '김해',
#  '국제공항',
#  '국제선',
#  '청사',
#  '항공',
#  '편',
#  '탑승',
#  '수속',
#  '여행객',
#  '북적',
#  '국제',
#  '신문',
#  '국제',
#  '신문',
#  '취재',
#  '종합',
#  '추석',
#  '연휴',
#  '김해',
#  '국제공항',
#  '국내외',
#  '항공',
#  '편',
#  '률',
#  '가파르',
#  '이',
#  '기간',
#  '에어부산',
#  '국제선',
#  '항공',
#  '편',
#  '률',
#  '를',
#  '일본',
#  '오사카',
#  '후쿠오카',
#  '베트남',
#  '나트랑',
#  '노선',
#  '순',
#  '인기',
#  '에어부산',
#  '국내선',
#  '항공',
#  '편',
#  '예약',
#  '률',
#  '역시',
#  '달',
#  '다음',
#  '달',
#  '개천절',
#  '부산',
#  '에어부산',
#  '국내선',
#  '항공',
#  '편',
#  '만석',
#  '제주항공',
#  '일본',
#  '노선',
#  '률',
#  '기록',
#  '중이',
#  '오사카',
#  '초반',
#  '도쿄',
#  '후쿠오카',
#  '중반',
#  '예약',
#  '제주항공',
#  '대한항공',
#  '대만',
#  '등',
#  '동남아',
# ...
