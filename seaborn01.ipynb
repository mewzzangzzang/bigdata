# %%
import numpy as np
import pandas as pd
import matplotlib 
import matplotlib.pylab as plt
import seaborn as sns

from matplotlib import rc, font_manager

# %% [markdown]
# import matplotlib.pylab as plt
# 그림, 저장시 필요
# from matplotlib import rc, font_manager
# 한글적용
# https://seaborn.pydata.org/examples/index.html

# %%
sns.set(style='whitegrid') #스타일 지정
# 한글인코딩위한 폰트설정
fontpath='c:/Windows/Fonts/malgun.ttf'
font_name=font_manager.FontProperties(fname=fontpath).get_name()
rc('font', family=font_name)

# -음수 자동 유니코드  설정
plt.rcParams['axes.unicode_minus']=False
# 차트 피규어 크기 설정
plt.rcParams['figure.figsize']=(12,9)

# %%
sns.get_dataset_names() #seaborn에 제공하는 데이터셋 검색
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanic=sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x='class', data=titanic, hue='who')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(y='class', data=titanic, hue='who',palette='YlGn')
# Out:
# <Axes: xlabel='count', ylabel='class'>

# %%
sns.countplot(x='day', data=tips, hue='time',palette='seismic')
# 그래프 축, data- frame, hue - 분류할 값,  palette- 색상
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
current_palette = sns.color_palette()
sns.palplot(sns.color_palette('RdBu'))
plt.show()
sns.palplot(sns.color_palette("Set1",10))
plt.show()

# %%
# sns.palplot(sns.color_palette("Greys"))
# plt.show()

# %%
# sns.palplot(sns.color_palette("dark",10))
# # 톤컬러, 수
# plt.show()

# color = ["green", "White", "Red", "Yellow", "Green", "Grey"]
# sns.set_palette(color)
# sns.palplot(sns.color_palette())
# plt.show()

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.relplot(x='total_bill', y='tip', data=tips)

# %%
tips['total_bill'].corr(tips['tip'])
sns.relplot(x='total_bill', y='tip', data=tips)

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='sex')
plt.title('tips',fontsize=16)
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker',style='sex')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='size', size='size')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker',palette='prism', row='sex', col='day')

# %%
df=pd.DataFrame(dict(time=np.arange(0,500,1),value=np.random.randn(500).cumsum()))
df
sns.relplot(x='time',y='value',data=df,kind='line')
sns.lineplot(x='time', y='value',data=df)
# Out:
# <Axes: xlabel='time', ylabel='value'>

# %%
fmri=sns.load_dataset('fmri')
fmri 
# timepoint x
# signal y
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
# x에 대한 값이 여러가지일때 어떻게 해야하는가
sns.relplot(x='timepoint',y='signal',data=fmri,kind='line', ci='sd')
# 평균값 , 표기할 값 , ci= 신뢰구간 ('sd'는 표준편차)
# Out:
# c:\Users\it\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,kind='line', estimator=None)
# estimator=None 추정회귀선

# %%
x=np.random.randn(100)
sns.histplot(data=x, kde=True)
sns.rugplot(x=x)
# 이게 지금 뭐냐면 이 구간에 값이 5개있는데 실제로 값의 상세정보는 안보이니까
# rugplot을 한다면 상세하게 보인다.
# Out:
# <Axes: ylabel='Count'>

# %%
data=np.random.rand(5,6)
sns.heatmap(data,annot=True)
# Out:
# <Axes: >

# %%
corr=tips.corr()
corr
# Out:
# C:\Users\it\AppData\Local\Temp\ipykernel_4400\1806571843.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=tips.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True, cmap='Reds')
# annot=안의 숫자값표기
# Out:
# <Axes: >

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='violin', hue='sex',
split=True, inner='stick')

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='swarm')
# 데이터가 많은 경우에는 비추천

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='boxen')
# sns.catplot(x='day',y='total_bill',data=tips,kind='box')

# %%
sns.catplot(x='day',y='total_bill',data=tips,hue='smoker',kind='bar')
# 오차, 크기비교에 주로 사용 
# 보통 카테고리(catplot)는 어디에 많이 분포되어있는가?

# %%
sns.pairplot(tips)
plt.show() 
# 각 구간별 히스토그램, 각 구간별 분포도 산출

# %%
sns.pairplot(tips,hue='size')
# size가 그리드에서 제외됩니다

# %%
sns.lmplot(x='total_bill', y='tip',hue='smoker', data=tips, col='day', col_wrap=2)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')
